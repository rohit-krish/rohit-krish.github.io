# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %%
# def f1d(std, mean):
x = np.linspace(-5, 5, 100)

def f(x):
    std = 1.4
    mean = 0
    return 1/(std*np.sqrt(2*np.pi)) * np.exp(-1/2 * ((x-mean)/std)**2)

plt.plot(x, f(x) );

# %%
def f(x, y):
    sigma = 1.3
    return 1/(2*np.pi*sigma**2) * np.exp(-(x**2 + y**2)/(2*sigma**2))

x_min = -2
x_max = 2
y_min = -2
y_max = 2
resolution = 8

X, Y = np.meshgrid(np.linspace(x_min, x_max, resolution), np.linspace(y_min, y_max, resolution))

Z = f(X, Y)

# %%
# 8, 10, 15, 49

# %%
# plt.imshow(Z)
from matplotlib import colormaps

cmaps = list(colormaps)

# %%
idx = 49
cur_cmap = cmaps[idx]

fig, ax = plt.subplots(nrows=1, ncols=1)
ax = fig.add_subplot(1, 1, 1)
ax.set_facecolor('xkcd:salmon')

plt.title(f'{cur_cmap} | {idx}')
plt.tight_layout();
# idx += 1

# sb.heatmap(Z, annot=True, cmap=cur_cmap)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

COLOR = '#afb0b1'
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = COLOR
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR
 
x = np.arange(0, 10, .1)
y = np.sin(x)
 
plt.figure(facecolor='#1b1b1e')
 
sb.heatmap(Z, annot=True, cmap=cur_cmap, cbar=True);
